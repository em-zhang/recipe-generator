# %% [markdown]
# Based on tutorial from https://towardsdatascience.com/pre-trained-word-embedding-for-text-classification-end2end-approach-5fbf5cd8aead

# %%
import pickle
import numpy as np
import pandas
from sklearn.model_selection import train_test_split

# %%
# open and load data from pickle file
file = open('FlavorGraph_NodeEmbedding.pickle', 'rb')

# keys are strings for node_id, value is embedding
data = pickle.load(file)

file.close()

# %%
# load dataframe of node_ids and ingredients
df = pandas.read_csv('nodes_191120.csv')

# %%
# just get the embeddings for ingredients
ing_embeddings = {}

for i in range(len(df)):
    if df.loc[i, 'node_type'] == "ingredient":
        # map the name of the ingredient to the embedding
        ing_embeddings[df.loc[i, 'name']] = data[str(df.loc[i, 'node_id'])]

# %%
# open and load data from pickle file
ner_embeddings_file = open('ner_embeddings.pkl', 'rb')

# keys are strings for node_id, value is embedding
ner_embeddings = pickle.load(ner_embeddings_file)

ner_embeddings_file.close()

# %%
subset= ner_embeddings.sample(n=1000)

# %%
subset
# Out:
#                                                        NER  \
# 200351   [flour, butter, cream_cheese, egg, nut, vanill...
# 403632   [broccoli, butter, flour, chicken_broth, milk,...
# 1144085  [bread, mustard, gruyere_cheese, ham, egg, mil...
# 1844687    [water, salt, yellow_cornmeal, unsalted_butter]
# 1878148  [elbow_macaroni, unsalted_butter, flour, salt,...
# ...                                                    ...
# 1685750  [butter, caster_sugar, cake_flour, egg, cocoa,...
# 1345394  [noodle, butter, cream, cheese, salt, white_pe...
# 1971297  [sage, lemon, light_brown_sugar, bourbon, selt...
# 788025   [egg, sugar, white_corn_syrup, butter, vanilla...
# 1875527  [flour, salt, vegetable_shortening, cooking_ap...
#
#                                                 embeddings  num_ingredients  \
# 200351   [[-0.31055188, 0.15737705, -0.012394806, 0.129...                7
# 403632   [[0.1542786, -0.27851453, -0.13236007, -0.0205...                6
# 1144085  [[0.17803018, 0.19869211, 0.01149651, 0.133690...                7
# 1844687  [[-0.21423446, 0.15547827, 0.31892928, -0.1390...                4
# 1878148  [[0.024601204, -0.091455914, -0.124858074, 0.0...                8
# ...                                                    ...              ...
# 1685750  [[-0.4366374, 0.026041824, 0.15680166, 0.11945...               11
# 1345394  [[0.05714173, -0.1908837, 0.10261169, -0.23282...                7
# 1971297  [[0.05544757, -0.013600926, -0.3245321, -0.059...                5
# 788025   [[0.25692862, 0.08700464, 0.23288268, 0.169938...                7
# 1875527  [[-0.31055188, 0.15737705, -0.012394806, 0.129...               13
#
#           start_ingredient
# 200351             vanilla
# 403632            broccoli
# 1144085     gruyere_cheese
# 1844687    yellow_cornmeal
# 1878148    unsalted_butter
# ...                    ...
# 1685750                egg
# 1345394              cream
# 1971297  light_brown_sugar
# 788025                 egg
# 1875527           cinnamon
#
# [1000 rows x 4 columns]

# %%
X_train
# Out:
# 974134                     curry
# 1316099                    bread
# 301080     buttermilk_baking_mix
# 708829          lean_ground_beef
# 42881                   broccoli
#                    ...
# 910635                ginger_ale
# 1839676                olive_oil
# 1241718               buttermilk
# 1434718                    cocoa
# 467784                    cheese
# Name: start_ingredient, Length: 800, dtype: object

# %%
print(y_train)
# Out:
# [list(['fennel', 'onion', 'butter', 'stock', 'chervil'])
#  list(['gin', 'white_rum', 'vodka', 'pineapple_juice', 'pineapple', 'passion_fruit', 'orange', 'mint'])
#  list(['flour', 'baking_soda', 'baking_powder', 'salt', 'ground_cinnamon', 'white_sugar', 'unsweetened_applesauce', 'egg', 'egg', 'vanilla', 'carrot', 'walnut', 'pineapple'])
#  list(['flour', 'sugar', 'pumpkin', 'cinnamon', 'egg', 'oil'])
#  list(['cake', 'egg', 'oil', 'almond_extract', 'cherry_pie_filling'])
#  list(['onion', 'mayonnaise', 'cheddar_cheese', 'roll'])
#  list(['cauliflower', 'onion_soup_mix', 'egg', 'mayonnaise'])
#  list(['light_mayonnaise', 'lemon_juice', 'fresh_cilantro', 'garlic', 'ground_cumin', 'paprika', 'cayenne_pepper'])
#  list(['chicken_breast', 'chicken', 'pork', 'veal', 'onion', 'butter', 'egg', 'parsley', 'salt', 'ground_allspice', 'lemon', 'pepper'])
#  list(['ground_beef', 'onion', 'green_pepper', 'garlic', 'tomato_paste', 'sugar', 'salt', 'pepper', 'oregano', 'bay_leaf'])
#  list(['cucumber', 'vinegar', 'mayonnaise'])
#  list(['green_pepper', 'pimento', 'sour_cream', 'pepper'])
#  list(['flour', 'cottage_cheese', 'egg', 'milk', 'baking_powder', 'chive', 'salt', 'margarine'])
#  list(['hamburger', 'rolled_oat', 'milk', 'egg', 'pepper', 'tarragon', 'onion_soup_mix', 'water', 'parmesan_cheese'])
#  list(['oil', 'sugar', 'egg', 'vanilla', 'flour', 'cinnamon', 'nutmeg', 'salt', 'baking_powder', 'baking_soda', 'pumpkin', 'pecan'])
#  list(['marshmallow', 'walnut', 'milk', 'butter', 'chocolate_chip'])
#  list(['flour', 'sugar', 'oil', 'cinnamon', 'baking_soda', 'baking_powder', 'salt', 'egg', 'pecan', 'carrot'])
#  list(['nori', 'sushi_rice', 'rice_wine_vinegar', 'sesame_seed', 'carrot', 'cucumber', 'avocado', 'water', 'hoisin_sauce'])
#  list(['crescent_roll', 'cream_cheese', 'sugar', 'vanilla', 'sugar', 'cinnamon', 'butter'])
#  list(['cabbage', 'salt', 'sugar', 'vinegar', 'salad_dressing', 'celery'])
#  list(['lemon_juice', 'sugar', 'water'])
#  list(['breadcrumb', 'garlic', 'lemon_zest', 'kosher_salt', 'fresh_ground_black_pepper', 'flour', 'egg', 'chicken_breast', 'oil'])
#  list(['pineapple', 'cheddar_cheese', 'whipped_cream_cheese', 'cracker'])
#  list(['chicken', 'pineapple', 'canola_oil', 'white_wine', 'soy_sauce', 'mustard', 'onion', 'mushroom', 'red_bell_pepper', 'green_olive'])
#  list(['white_sugar', 'egg', 'shortening', 'salt', 'lemon', 'baking_soda', 'milk', 'milk', 'flour'])
#  list(['egg', 'sugar', 'milk', 'cream', 'heavy_whipping_cream', 'vanilla'])
#  list(['sugar', 'flour', 'cocoa', 'baking_powder', 'salt', 'milk', 'margarine', 'vanilla', 'brown_sugar', 'water'])
#  list(['yeast', 'water', 'sugar', 'buttermilk', 'flour', 'baking_powder', 'baking_soda', 'salt', 'sugar', 'shortening'])
#  list(['lemon_juice', 'cider_vinegar', 'vegetable_oil', 'soy_sauce', 'sugar', 'salt', 'paprika', 'chili_powder', 'garlic_salt', 'pepper', 'onion', 'chicken'])
#  list(['strawberry', 'banana', 'carrot', 'celery'])
#  list(['parsley', 'celery', 'thyme', 'bay_leaf'])
#  list(['maple_syrup', 'flour', 'mustard', 'lemon_juice', 'ground_ginger', 'honey', 'orange_juice', 'brown_sugar', 'apricot', 'pineapple_juice', 'brown_sugar', 'mustard', 'horseradish', 'red_currant'])
#  list(['warm_water', 'yeast', 'sugar', 'shortening', 'salt', 'egg', 'flour', 'whole_kernel_corn'])
#  list(['butter', 'parsley', 'stock', 'lemon_juice', 'mayonnaise', 'white_pepper', 'egg_yolk', 'flour', 'chili_powder', 'salt'])
#  list(['pasta', 'butter', 'parmesan_cheese', 'milk', 'egg', 'bacon'])
#  list(['crabmeat', 'celery', 'mustard', 'sweet_pickle_relish', 'green_onion', 'mayonnaise', 'cracker'])
#  list(['pasta', 'butter', 'bacon', 'chicken_breast', 'butter', 'flour', 'milk', 'cheddar_cheese', 'salt'])
#  list(['chicken', 'olive_oil', 'garlic', 'parsley', 'salt', 'ground_cinnamon', 'white_wine'])
#  list(['condensed_milk', 'irish_whiskey', 'instant_coffee', 'chocolate_syrup', 'egg', 'vanilla'])
#  list(['milk', 'white_distilled_vinegar', 'flour', 'salt', 'lard', 'butter', 'buttermilk', 'butter'])
#  list(['spinach', 'egg', 'cottage_cheese', 'butter', 'flour', 'cheddar_cheese'])
#  list(['rice', 'pumpkin', 'egg', 'milk', 'salt', 'sugar', 'butter', 'nutmeg', 'cinnamon', 'vanilla'])
#  list(['salmon', 'lemon_juice', 'butter', 'sour_cream', 'mayonnaise', 'dijon_style_mustard', 'dill'])
#  list(['butternut_squash', 'ginger', 'unsalted_butter', 'salt', 'onion', 'chicken_stock', 'beef_stock', 'cinnamon'])
#  list(['cream_cheese', 'sour_cream', 'fruit_cocktail', 'pineapple_tidbit', 'orange'])
#  list(['cream_cheese', 'sugar', 'lemon_juice', 'roll', 'powdered_sugar', 'lemon_juice'])
#  list(['clove', 'apple_cider', 'pineapple_juice', 'water', 'cinnamon'])
#  list(['egg', 'sugar', 'salt', 'milk', 'vanilla_extract', 'cinnamon', 'light_brown_sugar', 'instant_coffee'])
#  list(['broccoli', 'butter', 'mushroom_soup', 'minute_rice', 'milk', 'cheddar_cheese', 'onion'])
#  list(['light_brown_sugar', 'light_syrup', 'milk', 'egg', 'vanilla', 'salt', 'pecan'])
#  list(['sausage', 'egg', 'cheddar_cheese'])
#  list(['cabbage', 'balsamic_vinegar', 'chicken', 'white_sugar', 'olive_oil', 'green_onion', 'almond', 'sesame_seed'])
#  list(['cream_cheese', 'butter', 'brown_sugar', 'vanilla', 'powdered_sugar'])
#  list(['margarine', 'flour', 'salt', 'sugar', 'vanilla', 'walnut'])
#  list(['pork_chop', 'onion', 'brown_sugar', 'barbecue_sauce', 'pineapple'])
#  list(['onion', 'butter', 'whole_kernel_corn', 'cream_style_corn', 'sour_cream', 'corn_muffin', 'pepper', 'salt'])
#  list(['apple_cider', 'chicken_broth', 'milk', 'garlic', 'white_button_mushroom', 'celery', 'onion', 'jalapeno', 'green_onion', 'broccoli', 'cornstarch', 'water', 'black_pepper', 'salt', 'cheddar_cheese', 'gouda_cheese', 'provolone_cheese'])
#  list(['shrimp', 'bacon', 'okra', 'garlic_salt', 'pepper', 'soy_sauce', 'bacon_grease'])
#  list(['butter', 'romaine_lettuce_heart', 'chicken', 'carrot', 'salt', 'lemon_juice'])
#  list(['butter', 'brown_sugar', 'syrup', 'egg', 'vanilla', 'salt', 'chocolate_chip', 'raisin', 'ground_cinnamon'])
#  list(['sour_cream', 'cheddar_cheese', 'bacon_bit'])
#  list(['morel', 'water', 'chicken', 'olive_oil', 'white_wine', 'leek', 'chicken_broth', 'thyme'])
#  list(['chive', 'mushroom', 'bell_pepper', 'butter', 'curry', 'rice', 'cream_of_chicken_soup', 'chicken_broth', 'chicken', 'lemon_pepper'])
#  list(['macaroni', 'milk', 'sweet_milk', 'salt', 'black_pepper', 'cheddar_cheese', 'cheddar_cheese', 'margarine', 'egg'])
#  list(['egg_noodle', 'cottage_cheese', 'sour_cream', 'onion', 'worcestershire_sauce', 'garlic_salt', 'parmesan_cheese', 'paprika'])
#  list(['milk', 'chicken_broth', 'bacon', 'red_onion', 'celery', 'scallion', 'flour', 'cheddar_cheese', 'tabasco_sauce', 'worcestershire_sauce', 'salt', 'pepper', 'fresh_chive'])
#  list(['string_bean', 'onion', 'ground_beef', 'butter', 'salt', 'pepper', 'nutmeg', 'sugar', 'egg', 'lemon_juice'])
#  list(['venison', 'beer', 'onion_soup'])
#  list(['sugar', 'egg', 'boiling_water', 'cake_flour', 'baking_powder', 'salt'])
#  list(['bisquick', 'hot_sausage', 'cheddar_cheese', 'milk'])
#  list(['condensed_milk', 'milk', 'egg', 'egg_yolk', 'vanilla', 'coconut'])
#  list(['egg', 'milk', 'fresh_chive', 'salt', 'butter', 'swiss_cheese', 'cheddar_cheese', 'parmesan_cheese'])
#  list(['egg', 'ground_pork', 'fresh_ginger', 'garlic', 'ground_cumin', 'salt', 'yellow_onion'])
#  list(['vegetable_oil', 'turkey_sausage', 'red_bean', 'water', 'green_onion'])
#  list(['butter', 'sugar', 'egg', 'vanilla', 'salt', 'baking_powder', 'flour'])
#  list(['chicken_breast', 'beef', 'sour_cream', 'cream_of_mushroom_soup'])
#  list(['firm_tofu', 'cottage_cheese', 'cream_cheese', 'parmesan_cheese', 'parsley_flake', 'mozzarella_cheese', 'salt', 'pepper', 'spaghetti_sauce'])
#  list(['beef', 'onion', 'celery', 'parsley', 'water', 'lemon_juice', 'brown_sugar', 'worcestershire_sauce', 'mustard', 'catsup'])
#  list(['gin', 'lemon_juice', 'simple_syrup', 'champagne'])
#  list(['cream_cheese', 'mayonnaise', 'onion', 'celery', 'beef', 'salt'])
#  list(['vinegar', 'water', 'sugar', 'canning_salt', 'garlic', 'dill', 'peppercorn', 'carrot', 'onion', 'mustard_seed', 'celery_seed'])
#  list(['avocado', 'cilantro', 'lime', 'goat_cheese', 'honey', 'salt', 'white_bread', 'cucumber'])
#  list(['sausage', 'egg', 'ranch_dressing', 'salsa', 'cheddar_cheese', 'bean', 'salt'])
#  list(['southern_comfort', 'cranberry_juice', 'lime_juice'])
#  list(['almond', 'flour', 'flour', 'sugar', 'kosher_salt', 'orange', 'anise', 'unsalted_butter', 'egg_yolk', 'powdered_sugar'])
#  list(['red_wine', 'honey', 'orange', 'cinnamon_stick', 'clove', 'vanilla', 'peppercorn', 'orange_zest'])
#  list(['egg', 'brown_sugar', 'vanilla', 'flour', 'baking_soda', 'salt', 'walnut'])
#  list(['sugar', 'unflavored_gelatin', 'milk', 'chunky_peanut_butter', 'graham_cracker_crust'])
#  list(['crisco', 'sugar', 'milk', 'egg', 'graham_cracker_crumb', 'baking_powder', 'vanilla', 'nut'])
#  list(['vanilla_caramel', 'milk', 'flour', 'oat', 'brown_sugar', 'baking_soda', 'salt', 'egg', 'margarine', 'chocolate_chip', 'walnut'])
#  list(['pepper', 'lard', 'baking_powder', 'kosher_salt', 'masa_harina', 'chicken_broth', 'vegetable_oil', 'scallion', 'garlic', 'chipotle_chile', 'ground_cumin', 'orange_zest', 'plantain', 'caper', 'banana'])
#  list(['salt', 'spanish_olive_oil', 'garlic', 'shallot', 'basil', 'thyme', 'oregano', 'salt'])
#  list(['butterscotch_chip', 'butter', 'brown_sugar', 'egg', 'vanilla', 'flour', 'baking_powder', 'salt', 'marshmallow', 'chocolate'])
#  list(['butter', 'brown_sugar', 'egg', 'vanilla', 'oat', 'flour', 'salt', 'nut', 'fruit_preserve'])
#  list(['popcorn', 'margarine', 'light_corn_syrup', 'brown_sugar', 'salt', 'baking_soda', 'cream_of_tartar', 'vanilla'])
#  list(['sugar', 'water', 'pineapple_juice', 'ginger_ale'])
#  list(['butter', 'vanilla'])
#  list(['ground_beef', 'onion', 'salt', 'rice', 'egg'])
#  list(['cream_cheese', 'powdered_sugar', 'graham_cracker_pie_crust', 'smooth_peanut_butter'])
#  list(['pineapple', 'cherry_pie_filling', 'milk', 'walnut'])
#  list(['flour', 'baking_powder', 'baking_soda', 'salt', 'butter', 'sugar', 'brown_sugar', 'rolled_oat', 'egg', 'vanilla', 'coconut'])
#  list(['mayonnaise', 'onion', 'garlic', 'parsley', 'sour_cream', 'lemon_juice', 'white_vinegar', 'blue_cheese', 'salt'])
#  list(['yellow_squash', 'salt', 'egg', 'sour_cream', 'flour', 'cheddar_cheese', 'bacon', 'bread', 'butter'])
#  list(['apple_cider', 'cranberry_juice', 'orange_juice', 'apricot_nectar', 'sugar', 'cinnamon_stick'])
#  list(['buttermilk', 'sugar', 'cinnamon', 'butter', 'brown_sugar', 'pecan'])
#  list(['sugar', 'flour', 'baking_soda', 'cinnamon', 'walnut', 'oil', 'egg', 'baking_powder', 'carrot'])
#  list(['macaroni', 'ground_beef', 'onion', 'tomato_sauce', 'italian_seasoning', 'oregano', 'pepper', 'garlic_powder', 'milk', 'mozzarella_cheese', 'egg'])
#  list(['sugar', 'oleo', 'egg', 'pineapple', 'white_bread', 'milk'])
#  list(['mango', 'mayonnaise', 'mustard', 'lemon_juice', 'cumin'])
#  list(['beef_mince', 'egg', 'breadcrumb', 'raisin', 'ground_cumin', 'curry_powder', 'oil', 'nut', 'ground_cinnamon', 'long_grain_rice', 'cinnamon', 'mint', 'parsley'])
#  list(['whole_chicken', 'lemon', 'tarragon'])
#  list(['garlic', 'cornflour', 'splenda_sugar_substitute', 'sesame_oil', 'mirin', 'soy_sauce'])
#  list(['chicken_breast', 'egg_white', 'parmesan_cheese', 'crouton'])
#  list(['olive_oil', 'onion', 'garlic', 'barley', 'vegetable_stock', 'bay_leaf', 'broccoli', 'zucchini', 'yellow_squash', 'carrot', 'water', 'salt'])
#  list(['cream_cheese', 'butter', 'onion', 'chipped_beef', 'garlic_powder'])
#  list(['flour', 'yellow_cornmeal', 'sugar', 'baking_powder', 'baking_soda', 'salt', 'egg', 'margarine', 'buttermilk', 'corn_kernel'])
#  list(['whole_wheat_spaghetti', 'sesame_dressing', 'shrimp', 'garlic', 'sesame_seed', 'vegetable', 'soy_sauce'])
#  list(['pasta_shell', 'onion', 'green_pepper', 'celery', 'butter', 'milk', 'mayonnaise', 'salt', 'ground_mustard', 'paprika', 'worcestershire_sauce', 'olive', 'imitation_crabmeat'])
#  list(['milk', 'margarine', 'cheese', 'garlic_salt', 'cracker', 'egg', 'salt', 'pepper'])
#  list(['water', 'catsup', 'brown_sugar', 'worcestershire_sauce', 'vinegar', 'butter', 'ham'])
#  list(['onion', 'ketchup', 'salad_oil', 'worcestershire_sauce', 'salt', 'sugar', 'white_vinegar'])
#  list(['egg', 'sugar', 'flour', 'vanilla', 'cherry_juice', 'light_raisin', 'dark_raisin', 'walnut', 'coconut'])
#  list(['white_bread', 'egg', 'onion', 'garlic', 'unsalted_butter', 'parsley', 'worcestershire_sauce', 'kosher_salt', 'black_pepper', 'ground_chuck', 'bread', 'romaine_leaf', 'bacon', 'onion', 'brown_sugar', 'mustard', 'ketchup', 'tomato'])
#  list(['frozen_spinach', 'water_chestnut', 'egg', 'bacon', 'vegetable_oil', 'sugar', 'lemon_juice', 'catsup', 'onion', 'worcestershire_sauce'])
#  list(['almond', 'sugar', 'icing_sugar', 'egg_white', 'almond'])
#  list(['parmesan_cheese', 'milk', 'egg', 'flour', 'butter', 'ground_nutmeg', 'salt', 'pepper'])
#  list(['turkey', 'rice', 'sour_cream', 'cream_of_chicken_soup', 'cream_of_mushroom_soup', 'broccoli', 'mushroom', 'swiss_cheese', 'cheddar_cheese'])
#  list(['chimichurri_sauce', 'feta_cheese', 'meatball', 'ground_beef', 'ground_pork', 'bread', 'milk', 'egg', 'chimichurri_sauce', 'scallion', 'garlic', 'pepper', 'baguette', 'lemon_slice', 'black_olive'])
#  list(['unsalted_butter', 'carrot', 'salt', 'fresh_ground_black_pepper', 'marjoram', 'flour', 'heavy_cream', 'garlic', 'breadcrumb'])
#  list(['ground_beef', 'onion', 'parsley', 'salt', 'black_pepper'])
#  list(['eggplant', 'yellow_squash', 'zucchini', 'okra', 'green_tomato', 'onion', 'green_pepper', 'flour', 'yellow_cornmeal', 'milk', 'salt', 'flour', 'yellow_cornmeal'])
#  list(['cauliflower', 'onion', 'broccoli', 'cucumber', 'sugar', 'oil', 'vinegar', 'celery'])
#  list(['yeast', 'water', 'sugar', 'salt', 'margarine', 'egg', 'flour'])
#  list(['butter', 'brown_sugar', 'flour', 'nut'])
#  list(['red_bell_pepper', 'wild_salmon', 'extra_virgin_olive_oil', 'caper', 'garlic', 'salt', 'black_pepper'])
#  list(['egg', 'sugar', 'vanilla', 'oil', 'zucchini', 'flour', 'salt', 'baking_soda', 'cinnamon', 'nut', 'date'])
#  list(['butter', 'sugar', 'egg', 'vanilla', 'flour', 'baking_soda', 'salt', 'nut', 'coconut'])
#  list(['cucumber', 'onion', 'green_bell_pepper', 'pickling_spice', 'vinegar', 'celery', 'turmeric', 'sugar'])
#  list(['chocolate', 'shortening'])
#  list(['cream_cheese', 'mustard', 'horseradish', 'parsley', 'onion', 'mayonnaise', 'chipped_beef'])
#  list(['salad_oil', 'lemon_juice', 'parmesan_cheese', 'salt', 'sugar', 'pepper', 'paprika', 'garlic'])
#  list(['cherry_pie_filling', 'mandarin_orange', 'pineapple', 'milk'])
#  list(['butter', 'sugar', 'egg', 'flour', 'lemon_juice', 'vanilla_extract', 'buttermilk', 'pecan', 'pastry_shell'])
#  list(['spinach', 'olive_oil', 'butter', 'bread', 'italian_salad_dressing', 'provolone_cheese', 'chicken', 'red_onion'])
#  list(['egg', 'parmesan_cheese', 'flour', 'salt', 'baking_soda', 'milk'])
#  list(['onion_soup', 'sour_cream'])
#  list(['hot_sauce', 'chili_powder', 'wine', 'sparerib', 'mustard', 'brown_sugar', 'ketchup', 'onion'])
#  list(['sugar', 'vanilla', 'egg', 'heavy_cream'])
#  list(['flour', 'sugar', 'baking_powder', 'baking_soda', 'salt', 'egg', 'buttermilk', 'oil', 'water'])
#  list(['mushroom', 'butter', 'onion', 'potato', 'celery', 'carrot', 'salt', 'pepper', 'flour', 'cold_water', 'boiling_water', 'milk', 'parmesan_cheese'])
#  list(['turkey_sausage', 'cabbage', 'spaghetti_sauce', 'mushroom', 'bell_pepper', 'garlic', 'italian_seasoning', 'onion', 'salt', 'pepper'])
#  list(['warm_water', 'yeast', 'kosher_salt', 'white_vinegar', 'flour', 'cornmeal'])
#  list(['ground_meat', 'onion', 'margarine', 'mushroom_soup', 'tomato_soup', 'pimento', 'velveeta_cheese', 'shell_macaroni'])
#  list(['tomato_puree', 'boiling_water', 'brown_sugar', 'salt', 'bread', 'butter'])
#  list(['flour', 'margarine', 'nut'])
#  list(['red_potato', 'onion', 'green_pepper', 'water', 'olive_oil', 'chicken_bouillon_granule', 'tomato', 'oregano'])
#  list(['cheese', 'green_onion', 'sugar'])
#  list(['cucumber', 'onion', 'vinegar', 'sugar', 'salt', 'celery'])
#  list(['butter', 'sugar', 'egg', 'banana', 'flour', 'baking_soda', 'date', 'nut'])
#  list(['fruit_cocktail', 'milk', 'lemon_juice', 'coconut', 'graham_cracker_crust'])
#  list(['tortellini', 'olive_oil', 'ham', 'turkey', 'pea', 'carrot', 'red_bell_pepper', 'parsley', 'garlic'])
#  list(['beef_brisket', 'onion_soup', 'water', 'potato', 'carrot', 'celery'])
#  list(['onion', 'cream_cheese', 'green_onion', 'beef', 'garlic', 'tabasco_sauce'])
#  list(['coconut', 'egg', 'vanilla', 'pie_shell', 'pecan', 'sugar', 'margarine', 'pinto_bean'])
#  list(['coconut', 'condensed_milk', 'vanilla'])
#  list(['shrimp', 'olive_oil', 'basil', 'parsley', 'oregano', 'garlic', 'onion_powder', 'black_pepper', 'red_pepper'])
#  list(['butter', 'flour', 'chicken_broth', 'cheddar_cheese', 'onion', 'white_pepper', 'worcestershire_sauce', 'light_cream'])
#  list(['chicken_breast', 'tomato', 'fresh_cilantro', 'salsa', 'flour_tortilla', 'cheddar_cheese', 'avocado', 'sour_cream'])
#  list(['prune', 'water', 'tart_apple', 'cinnamon', 'flour', 'cream', 'white_sugar', 'white_grape_juice', 'golden_raisin'])
#  list(['whole_grain_mustard', 'balsamic_vinegar', 'lemon_juice', 'salt', 'ground_black_pepper', 'olive_oil'])
#  list(['hamburger', 'elbow_macaroni', 'spaghetti_sauce', 'onion', 'bell_pepper', 'cheese'])
#  list(['bread', 'butter', 'parmesan_cheese', 'american_cheese', 'cheddar_cheese'])
#  list(['flour', 'lard', 'baking_powder', 'buttermilk'])
#  list(['water', 'salt', 'yellow_cornmeal', 'unsalted_butter'])
#  list(['light_butter', 'yellow_squash', 'vidalia_onion', 'chicken_broth', 'milk', 'thyme', 'salt', 'pepper', 'parmesan_cheese'])
#  list(['pumpkin', 'apple', 'apple_juice', 'brown_sugar', 'pumpkin_pie_spice'])
#  list(['meal', 'flour', 'onion', 'buttermilk'])
#  list(['ground_beef', 'white_bread', 'milk', 'egg', 'onion', 'salt', 'ketchup', 'water'])
#  list(['condensed_milk', 'chocolate_milk'])
#  list(['tomato', 'olive_oil', 'caper', 'garlic', 'lemon_rind', 'lemon_juice', 'thyme'])
#  list(['ladyfinger', 'strawberry', 'sugar', 'milk'])
#  list(['frozen_pea', 'green_pepper', 'celery', 'onion', 'cheddar_cheese', 'bacon_bit', 'plain_yogurt', 'sugar'])
#  list(['butter', 'flour', 'water', 'butter', 'water', 'almond', 'flour', 'egg', 'powdered_sugar', 'almond', 'butter'])
#  list(['heavy_cream', 'butter', 'ham', 'cognac', 'sage', 'italian_cheese'])
#  list(['red_wine', 'red_wine_vinegar', 'horseradish', 'ketchup', 'thyme', 'garlic', 'pepper', 'flank_steak'])
#  list(['spinach', 'frozen_pearl_onion', 'oregano', 'lemon_zest', 'lemon_juice', 'garlic', 'feta'])
#  list(['bacon', 'cheddar_cheese', 'green_onion', 'flour_tortilla', 'sour_cream'])
#  list(['ground_chicken', 'chunky_salsa', 'olive', 'roll', 'cheddar_cheese'])
#  list(['flour', 'salt', 'vegetable_shortening', 'cooking_apple', 'sugar', 'flour', 'cinnamon', 'nutmeg', 'egg', 'sugar', 'whipping_cream', 'sugar', 'cinnamon'])
#  list(['pizza_crust', 'pizza_sauce', 'cheddar_cheese', 'frozen_meatball', 'italian_seasoning'])
#  list(['milk', 'pineapple', 'pecan', 'frozen_lemonade'])
#  list(['egg', 'water', 'salt'])
#  list(['yellow_cornmeal', 'flour', 'sugar', 'baking_powder', 'salt', 'baking_soda', 'egg', 'buttermilk', 'butter', 'shortening'])
#  list(['flour', 'baking_powder', 'salt', 'milk', 'mayonnaise'])
#  list(['vodka', 'malibu_rum', 'liqueur', 'cranberry_juice', 'lemon_juice', 'grenadine'])
#  list(['lobster', 'boiling_water', 'salt', 'butter', 'egg', 'parmesan_cheese', 'fresh_shrimp'])
#  list(['chunky_peanut_butter', 'syrup', 'milk'])
#  list(['butter', 'cheddar_cheese'])
#  list(['apple', 'water', 'orange', 'cinnamon', 'sugar', 'pastry_crust'])
#  list(['egg', 'brown_sugar', 'white_sugar', 'vanilla', 'vegetable_oil', 'flour', 'oat', 'chocolate_chip'])
#  list(['crescent_roll', 'pepperoni', 'mozzarella_cheese', 'pizza_sauce'])
#  list(['flour', 'baking_soda', 'salt', 'cinnamon', 'brown_sugar', 'shortening', 'buttermilk', 'raisin', 'vanilla'])
#  list(['rice', 'onion_soup', 'cream_of_chicken_soup', 'milk', 'chicken'])
#  list(['flour', 'salt', 'ground_nutmeg', 'baking_soda', 'baking_powder', 'egg', 'white_sugar', 'vegetable_oil', 'zucchini', 'raisin'])
#  list(['sugar', 'cornstarch', 'boiling_water', 'butter', 'vanilla'])
#  list(['bread_flour', 'anise_seed', 'salt', 'fresh_yeast', 'greek_yogurt', 'honey', 'water'])
#  list(['onion', 'celery', 'butter', 'chicken', 'cream_of_chicken_soup', 'chicken_broth', 'lemon_juice', 'pepper', 'nutmeg', 'mushroom'])
#  list(['flour', 'sugar', 'salt', 'cocoa', 'baking_soda', 'oil', 'vinegar', 'vanilla', 'water'])
#  list(['garbanzo_bean', 'tahini', 'plain_yogurt', 'lemon', 'extra_virgin_olive_oil', 'garlic', 'salt', 'paprika', 'ground_cumin', 'ground_cayenne_pepper', 'cilantro'])
#  list(['cream_cheese', 'sugar', 'vanilla', 'vanilla_wafer', 'cherry'])
#  list(['coconut', 'nut', 'chocolate_cake', 'cream_cheese', 'powdered_sugar', 'margarine'])
#  list(['sugar', 'oil', 'egg', 'vanilla', 'flour', 'baking_soda', 'salt', 'cinnamon', 'clove', 'apple', 'nut'])
#  list(['egg', 'peanut_butter', 'butter', 'white_sugar', 'brown_sugar', 'flour', 'vanilla'])
#  list(['sugar', 'shortening', 'boiling_water', 'egg', 'yeast', 'water', 'salt', 'flour'])
#  list(['chicken', 'salt', 'water', 'carrot', 'celery', 'onion', 'noodle'])
#  list(['flour', 'baking_powder', 'sugar', 'cocoa', 'salt', 'shortening'])
#  list(['cabbage', 'rice', 'tomato_sauce', 'onion', 'garlic', 'mixed_herb'])
#  list(['flour', 'sugar', 'baking_soda', 'egg', 'brown_sugar', 'nut'])
#  list(['flour', 'salt', 'unsalted_butter', 'cream_cheese', 'sugar', 'cocoa', 'cinnamon', 'bittersweet_chocolate', 'egg', 'sugar'])
#  list(['sugar', 'cornstarch', 'salt', 'milk', 'heavy_whipping_cream', 'egg_yolk', 'vanilla_bean_paste'])
#  list(['margarine', 'sugar', 'egg', 'oil', 'sour_milk', 'vanilla', 'flour', 'baking_powder', 'salt', 'cinnamon', 'cocoa', 'baking_soda', 'clove', 'zucchini'])
#  list(['cream_cheese', 'cheese', 'onion', 'bell_pepper', 'pineapple', 'nut'])
#  list(['egg_white', 'sugar', 'coconut', 'pecan', 'salt', 'vanilla_wafer', 'vanilla', 'banana'])
#  list(['white_cake_mix', 'cream_of_coconut', 'milk', 'coconut'])
#  list(['fresh_ginger', 'clove', 'water', 'sugar', 'amber_rum', 'orange_slice'])
#  list(['egg_noodle', 'mushroom_soup', 'milk', 'tuna', 'fresh_ground_black_pepper', 'lemon_juice'])
#  list(['water', 'celery', 'shallot', 'sweet_pickle', 'mayonnaise', 'sour_cream', 'egg', 'salt', 'pepper', 'bread'])
#  list(['flour', 'baking_soda', 'salt', 'shortening', 'sugar', 'brown_sugar', 'egg', 'chocolate_chip', 'vanilla', 'nut'])
#  list(['shortening', 'sugar', 'egg', 'flour', 'baking_powder', 'baking_soda', 'salt', 'sour_milk', 'banana', 'vanilla', 'nut'])
#  list(['zucchini', 'carrot', 'onion', 'oregano', 'butter', 'cheddar_cheese_soup', 'cream_of_potato_soup', 'water', 'tomato_juice', 'chicken'])
#  list(['sugar', 'sour_cream', 'vanilla', 'pecan'])
#  list(['white_onion', 'garlic', 'lemon_juice', 'salt', 'tomato_sauce', 'olive_oil'])
#  list(['broccoli', 'celery', 'onion', 'chicken_broth', 'swiss_cheese', 'nonfat_milk', 'cornstarch', 'salt', 'pepper', 'thyme'])
#  list(['sugar', 'water', 'red_wine'])
#  list(['watermelon_rind', 'salt', 'alum', 'water', 'sugar', 'lemon', 'cinnamon_stick', 'ginger', 'whole_clove', 'allspice', 'water'])
#  list(['ground_beef', 'onion', 'taco_seasoning_mix', 'tomato_sauce', 'whole_kernel_corn', 'cheddar_cheese', 'bisquick_baking_mix', 'sour_cream', 'tomato', 'milk', 'egg'])
#  list(['pasta', 'parmesan_cheese', 'fresh_basil', 'garlic', 'olive_oil', 'nut', 'salt'])
#  list(['carrot', 'celery', 'green_pepper', 'onion'])
#  list(['margarine', 'sugar', 'egg', 'lemon_rind', 'lemon_juice', 'flour', 'milk', 'pastry_shell'])
#  list(['instant_polenta', 'flour', 'sugar', 'baking_powder', 'salt', 'unsalted_butter', 'vegetable_shortening', 'lemon', 'egg', 'poppy_seed', 'sorbet'])
#  list(['active_dry_yeast', 'milk', 'shortening', 'sugar', 'salt', 'egg', 'flour', 'butter'])
#  list(['butter', 'sugar', 'egg', 'flour', 'oatmeal', 'cinnamon', 'nutmeg', 'raisin'])
#  list(['cheese', 'pimento', 'sweet_pickle', 'egg'])
#  list(['milk', 'sugar', 'egg', 'cornstarch', 'vanilla', 'cream_cheese'])
#  list(['brown_sugar', 'butter', 'chocolate_chip', 'nut', 'cracker'])
#  list(['sugar', 'egg', 'shortening', 'pumpkin', 'flour', 'baking_powder', 'date', 'baking_soda', 'salt', 'cinnamon', 'clove', 'water', 'nut'])
#  list(['water', 'butter', 'cider_vinegar', 'powdered_milk', 'honey', 'sugar', 'salt', 'bread_flour', 'whole_wheat_flour', 'oatmeal', 'yeast'])
#  list(['flour', 'salt', 'steak', 'butter', 'onion', 'water', 'sour_cream'])
#  list(['whole_kernel_corn', 'onion', 'pimiento', 'cheddar_cheese', 'cracker_crumb', 'egg', 'butter', 'sugar'])
#  list(['catsup', 'onion', 'brown_sugar', 'dry_mustard', 'salt', 'corn', 'bacon'])
#  list(['flour', 'butter', 'garlic', 'onion', 'worcestershire_sauce', 'salt', 'pepper', 'mustard', 'chicken_broth', 'beer', 'cheddar_cheese'])
#  list(['butter', 'chicken_breast', 'water', 'honey', 'garlic', 'salt', 'worcestershire_sauce'])
#  list(['green_cabbage', 'purple_cabbage', 'salad_oil', 'vinegar', 'sugar', 'salt', 'mustard', 'onion', 'celery'])
#  list(['bacon', 'water_chestnut', 'dark_brown_sugar', 'cajun_seasoning', 'toothpick'])
#  list(['water', 'salt', 'white_sugar', 'cheddar_cheese', 'jalapeno_pepper', 'bread_flour', 'active_dry_yeast'])
#  list(['butter', 'chive', 'parsley', 'corn'])
#  list(['hen', 'onion', 'egg_noodle', 'pepper', 'mushroom_soup', 'cheese', 'celery'])
#  list(['flour', 'ground_ginger', 'bicarbonate_of_soda', 'egg', 'butter', 'caster_sugar', 'golden_syrup'])
#  list(['shell_macaroni', "campbell's_cheddar_cheese_soup", 'milk'])
#  list(['lean_ground_beef', 'bean_sprout', 'water_chestnut', 'salt', 'soy_sauce'])
#  list(['butter', 'onion', 'thyme', 'beef', 'white_wine', 'swiss_cheese'])
#  list(['apple', 'walnut', 'cinnamon_sugar', 'lemon_juice', 'butter', 'cream_cheese', 'powdered_sugar', 'flour_tortilla', 'caramel_sauce', 'vanilla_ice_cream'])
#  list(['chicken_breast', 'butter', 'lemon', 'salt', 'paprika', 'oregano', 'garlic', 'pepper'])
#  list(['banana', 'egg', 'vegetable_oil', 'milk', 'sugar', 'salt', 'baking_soda', 'baking_powder', 'flour'])
#  list(['bread', 'mustard', 'gruyere_cheese', 'ham', 'egg', 'milk', 'cheddar_cheese'])
#  list(['flour', 'salt', 'shortening', 'cold_water', 'cooking_apple', 'lemon_juice', 'sugar', 'flour', 'ground_cinnamon', 'ground_nutmeg', 'raisin'])
#  list(['egg_yolk', 'sugar', 'whipping_cream', 'vanilla', 'salt', 'cookie'])
#  list(['flour', 'oatmeal', 'brown_sugar', 'butter', 'baking_soda', 'chocolate_chip', 'nut', 'salt'])
#  list(['brown_sugar', 'mustard', 'catsup', 'oregano', 'cider_vinegar', 'worcestershire_sauce', 'butter', 'pepper', 'salt', 'meat'])
#  list(['butter', 'coconut_milk', 'sugar', 'light_corn_syrup', 'vanilla', 'coconut_flavoring', 'salt', 'baking_powder', 'flour', 'coconut', 'chocolate_chip', 'condensed_milk', 'coconut', 'almond'])
#  list(['marshmallow', 'peanut_butter', 'bread', 'butter', 'marshmallow_cream'])
#  list(['cream_cheese', 'sugar', 'dream_whip', 'graham_cracker_crumb', 'oleo', 'blueberry_pie_filling'])
#  list(['ham', 'pineapple', 'brown_sugar', 'clove'])
#  list(['egg', 'oil', 'sugar', 'zucchini', 'cinnamon', 'salt', 'baking_powder', 'flour', 'baking_soda', 'nut'])
#  list(['pineapple_juice', 'egg', 'egg_yolk', 'sugar', 'unsalted_butter', 'salt', 'buttercream_frosting', 'orange_zest', 'orange_juice', 'angel_food_cake', 'mandarin_orange_section', 'coconut', 'pineapple'])
#  list(['macaroni', 'tuna', 'sweet_pickle_relish', 'egg', 'green_onion', 'mayonnaise'])
#  list(['mango', 'soy_sauce', 'honey', 'ground_ginger', 'lemon', 'lemon_juice', 'tabasco_sauce', 'chicken'])
#  list(['pear', 'cream_cheese', 'cream', 'salt'])
#  list(['chicken', 'water', 'ketchup', 'brown_sugar', 'worcestershire_sauce', 'vinegar', 'oleo', 'lemon_juice', 'mustard', 'chili_powder', 'paprika'])
#  list(['montrachet', 'grape', 'pistachio'])
#  list(['butternut_squash', 'olive_oil', 'onion', 'water', 'salt', 'pepper', 'milk', 'parmesan_cheese'])
#  list(['shortening', 'sugar', 'egg', 'banana', 'flour', 'baking_powder', 'baking_soda', 'salt'])
#  list(['pork_chop', 'garlic', 'apple', 'mustard', 'olive_oil', 'water'])
#  list(['egg', 'sugar', 'pumpkin', 'lemon_juice', 'flour', 'baking_powder', 'cinnamon', 'ginger', 'nutmeg', 'salt', 'walnut', 'powdered_sugar', 'cream_cheese', 'butter', 'vanilla'])
#  list(['mushroom', 'cottage_cheese', 'pepper', 'garlic', 'cayenne_pepper'])
#  list(['tuna', 'yogurt', 'corn', 'celery', 'dill_pickle', 'chive', 'fresh_ground_black_pepper', 'salt'])
#  list(['egg', 'baking_powder', 'water', 'salt'])
#  list(['unsalted_butter', 'sugar', 'egg', 'bittersweet_chocolate', 'ground_almond', 'salt'])
#  list(['marshmallow', 'cheese', 'cracker'])
#  list(['kidney_bean', 'green_bean', 'yellow_bean', 'sugar', 'oil', 'vinegar', 'green_pepper', 'onion', 'salt'])
#  list(['butter', 'sugar', 'almond', 'vanilla', 'flour', 'baking_cocoa', 'salt', 'chocolate_chip', 'sugar', 'coconut'])
#  list(['pork_chop', 'brown_sugar', 'red_pepper', 'paprika', 'lime', 'vinegar', 'soy_sauce'])
#  list(['chicken', 'butter', 'hot_sauce', 'cayenne_pepper', 'celery_salt', 'onion_powder', 'garlic', 'celery'])
#  list(['boiling_water', 'butter', 'sugar', 'brown_sugar', 'vanilla', 'egg', 'flour', 'baking_soda', 'salt', 'cinnamon', 'nutmeg', 'butter', 'brown_sugar', 'light_cream', 'nut', 'flaked_coconut'])
#  list(['cream_cheese', 'egg', 'sugar', 'vanilla', 'milk', 'cornstarch', 'vanilla_yogurt'])
#  list(['wild_rice', 'water', 'salt', 'ground_beef', 'mushroom', 'celery', 'onion', 'butter', 'soy_sauce', 'sour_cream', 'salt', 'pepper', 'almond'])
#  list(['egg', 'cream_cheese', 'parmesan_cheese', 'pepper', 'butter', 'garlic'])
#  list(['bread', 'cream_cheese', 'scallion', 'dill', 'curry_powder', 'paprika', 'salt', 'cucumber', 'cream', 'vinegar', 'butter'])
#  list(['butter', 'unsweetened_applesauce', 'date', 'egg', 'vanilla', 'flour', 'baking_soda', 'ground_clove', 'cinnamon'])
#  list(['flour', 'baking_soda', 'salt', 'butter', 'granulated_sugar', 'brown_sugar', 'vanilla', 'egg', 'nut', 'white_chocolate'])
#  list(['apple', 'pear', 'brown_sugar', 'water', 'ground_cinnamon', 'ground_nutmeg', 'ground_clove', 'flour', 'vanilla', 'vanilla_ice_cream'])
#  list(['apple_juice', 'soy_sauce', 'vinegar', 'extract', 'mustard'])
#  list(['yellow_onion', 'green_onion', 'fresh_parsley', 'fresh_dill', 'feta_cheese', 'cottage_cheese', 'salt', 'olive_oil', 'egg', 'phyllo_dough'])
#  list(['butter', 'brown_sugar', 'egg', 'vanilla', 'flour', 'baking_powder', 'salt', 'chocolate_chip', 'nut'])
#  list(['chicken', 'cheese', 'parmesan_cheese', 'bacon', 'caesar_salad_dressing', 'mayonnaise', 'garlic', 'lemon_juice', 'red_pepper', 'fresh_ground_pepper', 'crescent_roll', 'caesar_salad_dressing'])
#  list(['flax_seed', 'almond_meal', 'baking_powder', 'baking_soda', 'salt', 'nutmeg', 'cinnamon', 'butter', 'egg', 'buttermilk', 'buttermilk', 'butter', 'sugar_substitute', 'cinnamon'])
#  list(['milk', 'marshmallow', 'pineapple', 'dream_whip', 'vanilla', 'graham_cracker'])
#  list(['vegetable_oil', 'olive_oil', 'vinegar', 'sugar', 'onion', 'salt', 'mustard', 'celery'])
#  list(['butter', 'flour', 'salt', 'paprika', 'cheddar_cheese', 'lemon', 'green_onion'])
#  list(['broccoli', 'rice', 'cream_of_mushroom_soup', 'water_chestnut', 'cheese'])
#  list(['egg', 'milk', 'brown_sugar', 'orange_juice', 'nutmeg', 'cinnamon', 'bread'])
#  list(['cooking_apple', 'gingerroot', 'sugar', 'lemon', 'butter'])
#  list(['water', 'butter', 'salt', 'flour', 'egg'])
#  list(['crabmeat', 'cream_cheese', 'sour_cream', 'onion', 'horseradish', 'salt', 'almond'])
#  list(['almond_flour', 'egg', 'oil', 'cornstarch', 'salt', 'date', 'egg', 'maple_syrup', 'vanilla', 'pecan'])
#  list(['margarine', 'cocoa', 'cream_cheese', 'condensed_milk', 'egg', 'vanilla', 'flour'])
#  list(['sugar', 'butter', 'egg_yolk', 'almond', 'flour', 'cocoa', 'chocolate_chip'])
#  list(['extra_lean_ground_beef', 'olive_oil', 'onion', 'green_pepper', 'paprika', 'salt_substitute', 'garlic', 'wild_rice', 'tomato_soup', 'salt', 'water', 'cabbage'])
#  list(['pineapple', 'flour', 'sugar', 'margarine', 'cheddar_cheese', 'roll'])
#  list(['margarine', 'butter', 'sugar', 'flour', 'vanilla', 'egg'])
#  list(['heavy_cream', 'egg', 'bourbon', 'espresso_granule', 'chocolate_chip'])
#  list(['ketchup', 'brown_sugar', 'worcestershire_sauce'])
#  list(['egg_white', 'flour', 'sugar', 'salt', 'cream_of_tartar', 'vanilla_extract', 'almond_extract'])
#  list(['butter', 'sugar', 'salt', 'yeast', 'milk', 'flour', 'sugar', 'cinnamon'])
#  list(['meal', 'flour', 'egg', 'buttermilk'])
#  list(['condensed_milk', 'lemon_juice', 'cherry_pie_filling', 'pineapple', 'marshmallow'])
#  list(['flour', 'cocoa', 'baking_soda', 'baking_powder', 'salt', 'butter', 'sugar', 'egg', 'vanilla', 'cooking_spray', 'sugar', 'meringue_powder', 'sugar'])
#  list(['bread', 'butter', 'garlic_bread'])
#  list(['bacon', 'onion', 'ketchup', 'brown_sugar', 'worcestershire_sauce', 'green_bean'])
#  list(['cherry_pie_filling', 'egg', 'water'])
#  list(['water', 'chicken_breast', 'pasta', 'chicken_broth', 'celery', 'onion', 'cream_of_mushroom_soup', 'cheese', 'parsley'])
#  list(['butter', 'whipping_cream', 'flour', 'sugar'])
#  list(['water', 'yeast', 'sugar', 'potato_flake'])
#  list(['vanilla_wafer_crumb', 'butter', 'powdered_sugar', 'vanilla', 'egg_yolk', 'cream', 'pineapple'])
#  list(['mushroom', 'green_onion', 'margarine', 'shrimp', 'white_wine', 'cream_cheese', 'milk', 'swiss_cheese'])
#  list(['oat', 'brown_sugar', 'white_sugar', 'flour', 'crisco', 'egg', 'nut', 'raisin', 'vanilla'])
#  list(['cracker', 'light_brown_sugar', 'butter', 'pecan'])
#  list(['red_onion', 'garlic', 'kosher_salt', 'avocado', 'fresh_coriander', 'tomato'])
#  list(['chicken_breast', 'flour', 'salt', 'egg'])
#  list(['garlic', 'salt', 'cabbage', 'butter'])
#  list(['eggplant', 'red_onion', 'kosher_salt', 'olive_oil', 'white_miso', 'mirin', 'rice_vinegar', 'brown_sugar', 'red_pepper', 'garlic', 'spaghetti', 'scallion'])
#  list(['sugar', 'margarine', 'egg', 'flour', 'cocoa', 'salt', 'vanilla_extract', 'pecan', 'whipped_cream'])
#  list(['butter', 'shortening', 'brown_sugar', 'egg', 'salt', 'vanilla', 'almond', 'flour', 'nut', 'strawberry'])
#  list(['egg', 'sugar', 'bisquick', 'milk', 'vanilla', 'margarine', 'coconut'])
#  list(['pork_chop', 'parmesan_cheese', 'mustard', 'olive_oil', 'apricot', 'splenda_sugar_substitute', 'water'])
#  list(['beef', 'onion', 'bell_pepper', 'cajun_seasoning', 'oil', 'water'])
#  list(['oil', 'egg', 'sugar', 'flour', 'baking_powder', 'salt', 'cinnamon', 'baking_soda', 'gala_apple', 'walnut', 'vanilla', 'butterscotch_chip'])
#  list(['tart_apple', 'sugar', 'flour', 'cinnamon', 'nutmeg', 'salt', 'butter'])
#  list(['chicken', 'cream_of_mushroom_soup', 'cream_of_chicken_soup', 'cream_of_celery_soup', 'orange_juice', 'parmesan_cheese', 'rice', 'almond', 'margarine'])
#  list(['salmon', 'cracker_crumb', 'celery_salt', 'pepper', 'salt', 'egg', 'milk', 'butter'])
#  list(['sugar', 'vegetable_oil', 'egg', 'ground_cinnamon', 'baking_powder', 'baking_soda', 'vanilla', 'ground_ginger', 'salt', 'flour', 'zucchini', 'walnut'])
#  list(['blue_cornmeal', 'flour', 'sugar', 'baking_powder', 'salt', 'milk', 'egg', 'vegetable_oil', 'butter'])
#  list(['honey', 'buttermilk', 'egg', 'baking_soda', 'salt', 'cornmeal', 'flour', 'baking_powder', 'butter'])
#  list(['flour', 'yeast', 'boiling_water', 'sugar', 'margarine', 'egg', 'shortening', 'salt', 'water'])
#  list(['rice', 'chicken', 'salt', 'chicken_soup', 'water', 'onion_soup'])
#  list(['egg', 'oil', 'white_sugar', 'vanilla', 'zucchini', 'nut', 'flour', 'baking_powder', 'salt', 'baking_soda', 'cinnamon'])
#  list(['simple_syrup', 'water', 'demerara_sugar', 'simple_syrup', 'gin', 'lemon_juice', 'simple_syrup', 'basil', 'basil'])
#  list(['flour', 'brown_sugar', 'sugar', 'peanut_butter', 'butter', 'baking_powder', 'baking_soda', 'milk', 'vanilla', 'egg', 'bittersweet_chocolate_chip', 'peanut_butter'])
#  list(['egg', 'breadcrumb', 'parsley', 'salt', 'pepper', 'oregano', 'lean_ground_beef', 'chicken_broth', 'egg_noodle'])
#  list(['ground_beef', 'onion', 'soy_sauce', 'carrot', 'raisin', 'parsley', 'walnut', 'egg_roll_wrap', 'egg'])
#  list(['corn_muffin', 'sour_cream', 'egg', 'oil', 'salt'])
#  list(['honey', 'mustard', 'hot_sauce', 'breadcrumb', 'parmesan_cheese', 'chicken'])
#  list(['sugar', 'butter', 'vegetable_shortening', 'egg', 'salt', 'flour', 'milk', 'almond'])
#  list(['baking_mix', 'milk', 'margarine', 'sugar', 'cinnamon'])
#  list(['baking_soda', 'water', 'applesauce', 'sugar', 'flour', 'cooking_oil', 'cinnamon', 'salt', 'walnut', 'raisin', 'date'])
#  list(['onion', 'vegetable_oil', 'cider_vinegar', 'sugar', 'mustard', 'celery', 'salt', 'black_pepper'])
#  list(['chicken', 'salt', 'black_pepper', 'lard', 'flour', 'onion', 'parsley', 'thyme', 'boiling_water', 'bay_leaf', 'country_ham', 'ground_cayenne_pepper', 'oyster', 'file_powder'])
#  list(['turkey_breast', 'plain_yogurt', 'lemon_juice', 'vegetable_oil', 'fresh_parsley', 'green_onion', 'garlic', 'fresh_dill', 'rosemary', 'salt', 'pepper'])
#  list(['heavy_cream', 'water'])
#  list(['brown_sugar', 'cider', 'whole_allspice', 'clove', 'cinnamon', 'orange_slice'])
#  list(['egg', 'buttermilk', 'almond', 'cinnamon', 'nutmeg', 'bread'])
#  list(['vegetable_oil', 'egg', 'salt', 'sour_cream'])
#  list(['tuna', 'onion_salt', 'worcestershire_sauce', 'horseradish', 'sour_cream', 'parsley'])
#  list(['water', 'honey', 'carrot', 'coriander_seed', 'extra_virgin_olive_oil', 'lemon_juice', 'mustard', 'salt', 'ground_black_pepper', 'ground_cumin'])
#  list(['chicken_breast', 'extra_virgin_olive_oil', 'lemon_juice', 'garlic', 'mint', 'fresh_oregano', 'salt', 'ground_black_pepper', 'red_onion', 'yellow_bell_pepper'])
#  list(['peanut_butter', 'sugar', 'baking_soda', 'egg'])
#  list(['cream_cheese', 'powdered_sugar', 'pineapple', 'walnut', 'vanilla', 'roll', 'coconut'])
#  list(['stewing_beef', 'stewing_veal', 'onion', 'flour', 'salt', 'pepper', 'boiling_water', 'parsley', 'noodle'])
#  list(['butter', 'cream_cheese', 'white_sugar', 'vanilla', 'orange_zest', 'egg', 'flour', 'salt', 'chocolate_chip', 'sugar', 'butter', 'orange_juice', 'orange_zest', 'salt'])
#  list(['egg', 'flour', 'pumpkin', 'lemon_juice', 'baking_powder', 'cinnamon', 'ginger', 'salt', 'pecan', 'sugar'])
#  list(['cream_cheese', 'cheddar_cheese', 'ham', 'onion', 'bell_pepper', 'garlic_powder'])
#  list(['chicken', 'flour', 'salt', 'pepper', 'vegetable_oil', 'celery', 'onion', 'bell_pepper', 'chicken_broth'])
#  list(['ground_ham', 'sweet_pickle_relish', 'brown_sugar', 'mayonnaise', 'mustard'])
#  list(['rum', 'orange_juice', 'cola'])
#  list(['pear', 'lemon_juice', 'water', 'sugar', 'sweet_sherry'])
#  list(['soy_sauce', 'chili_sauce', 'honey', 'salad_oil', 'green_onion', 'curry_powder'])
#  list(['chicken_breast', 'caster_sugar', 'oregano', 'cayenne_pepper', 'ground_cinnamon', 'onion', 'red_pepper', 'yellow_pepper', 'green_pepper', 'vegetable_oil', 'salsa', 'sour_cream'])
#  list(['ketchup', 'pepper', 'salt', 'salsa'])
#  list(['butter', 'sugar', 'egg', 'flour', 'milk', 'water', 'vanilla_extract', 'pastry_shell'])
#  list(['rolled_oat', 'sunflower_seed', 'date', 'apricot', 'salt', 'sunflower_seed_butter', 'honey', 'orange_zest'])
#  list(['fava_bean', 'chickpea', 'white_bean', 'flat_leaf_parsley', 'olive_oil', 'garlic', 'lemon', 'kosher_salt'])
#  list(['green_bean', 'whole_kernel_corn', 'pea', 'pimento', 'onion', 'vinegar', 'sugar', 'salad_oil'])
#  list(['corn', 'pepper', 'pepper', 'bell_pepper', 'white_pepper', 'butter'])
#  list(['sugar', 'egg', 'lemon_juice', 'vanilla', 'coconut', 'butter'])
#  list(['butter', 'milk', 'bread', 'sugar', 'vanilla', 'egg_white', 'egg', 'raisin', 'sugar', 'butter', 'egg', 'bourbon'])
#  list(['graham_cracker', 'nutella', 'marshmallow_cream'])
#  list(['rice', 'sugar', 'milk'])
#  list(['sage', 'lemon', 'light_brown_sugar', 'bourbon', 'seltzer_water'])
#  list(['bean', 'sour_cream', 'avocado', 'salt', 'lime_juice', 'red_onion', 'tomato', 'black_olive', 'mexican_cheese', 'tortilla_chip'])
#  list(['salt', 'polenta'])
#  list(['sugar', 'cocoa', 'flour', 'salt', 'egg_yolk', 'milk'])
#  list(['chicken_breast', 'cheese', 'ham', 'cream_of_chicken_soup', 'paprika'])
#  list(['white_bean', 'water', 'onion', 'garlic', 'olive_oil', 'tomato_paste', 'salt', 'bacon', 'ham_hock', 'sausage', 'chorizo_sausage', 'powdered_saffron'])
#  list(['white_rice', 'pork_chop', 'cornstarch', 'soy_sauce', 'fresh_ginger', 'pineapple', 'oil', 'pea', 'red_bell_pepper', 'cornstarch', 'soy_sauce'])
#  list(['broccoli', 'onion', 'green_pepper', 'cheddar_cheese', 'milk', 'bisquick', 'egg', 'salt', 'pepper'])
#  list(['mustard', 'lemon_juice', 'kosher_salt', 'fresh_ground_black_pepper', 'olive_oil', 'butter', 'avocado', 'red_onion'])
#  list(['elbow_macaroni', 'unsalted_butter', 'flour', 'salt', 'pepper', 'milk', 'american_cheese', 'breadcrumb'])
#  list(['soy_sauce', 'brown_sugar', 'worcestershire_sauce', 'chicken', 'cheddar_cheese', 'swiss_cheese'])
#  list(['onion', 'ketchup', 'vinegar', 'brown_sugar', 'tabasco_sauce', 'water', 'tomato_soup', 'salt', 'pork_chop'])
#  list(['cabbage', 'bacon', 'butter', 'chicken_broth', 'salt'])
#  list(['unsalted_butter', 'cake_flour', 'baking_powder', 'salt', 'sugar', 'vegetable_shortening', 'milk', 'vanilla', 'egg', 'almond'])
#  list(['greek_yogurt', 'horseradish_sauce', 'chicken', 'olive_oil', 'breadcrumb', 'salt'])
#  list(['milk', 'chocolate_cake', 'butter', 'chocolate_chip', 'walnut', 'caramel'])
#  list(['butter', 'garlic', 'onion', 'lemon_juice', 'worcestershire_sauce', 'grain', 'parsley', 'thyme', 'tarragon'])
#  list(['sugar', 'flour', 'baking_soda', 'salt', 'cinnamon', 'nutmeg', 'ground_clove', 'egg', 'vegetable_oil', 'water', 'pumpkin', 'walnut'])
#  list(['tater_tot', 'sour_cream', 'cream_of_mushroom_soup', 'cheddar_cheese', 'chicken_breast'])
#  list(['beer', 'buttermilk_baking_mix'])
#  list(['powdered_sugar', 'cream_cheese', 'cake', 'cherry_pie_filling'])
#  list(['apple', 'green_onion', 'curry_powder', 'water', 'cream_of_mushroom_soup', 'milk', 'parsley', 'chicken', 'yogurt'])
#  list(['whole_wheat_flour', 'salt', 'baking_powder', 'baking_soda', 'unsalted_butter', 'sugar', 'light_brown_sugar', 'honey', 'egg', 'vanilla', 'almond', 'quinoa', 'coconut', 'chocolate'])
#  list(['cream_cheese', 'sugar', 'lemon_peel', 'vanilla', 'orange_juice', 'whipping_cream'])
#  list(['tequila', 'apple_cider', 'lemon_juice'])
#  list(['flour', 'baking_soda', 'salt', 'cinnamon', 'sugar', 'cooking_oil', 'pineapple', 'walnut', 'vanilla', 'egg', 'carrot'])
#  list(['black_bean', 'water', 'green_pepper', 'onion', 'garlic', 'corn_oil', 'baking_soda', 'salt'])
#  list(['egg', 'milk', 'oil', 'flour', 'sugar', 'cinnamon'])
#  list(['butter', 'sugar', 'egg', 'vanilla', 'banana', 'flour', 'baking_soda', 'baking_powder', 'salt', 'sour_cream', 'nut'])
#  list(['brown_sugar', 'white_sugar', 'butter', 'egg', 'flour', 'coconut', 'oatmeal', 'vanilla', 'salt', 'raisin', 'baking_powder', 'nut'])
#  list(['green_onion', 'parmesan_cheese', 'mozzarella_cheese', 'ricotta_cheese', 'egg', 'pepper', 'nutmeg', 'jumbo_pasta_shell', 'marinara_sauce'])
#  list(['butter', 'sugar', 'egg', 'baking_powder', 'baking_soda', 'salt', 'vanilla', 'sour_cream', 'flour', 'nutmeg'])
#  list(['spinach', 'bacon', 'egg', 'sweet_onion', 'salt', 'mayonnaise', 'swiss_cheese'])
#  list(['margarine', 'onion', 'rice', 'curry', 'turmeric', 'lemon_zest', 'chicken_broth', 'chive', 'pepper'])
#  list(['sugar', 'brown_sugar', 'salt', 'baking_powder', 'vanilla', 'butter', 'egg'])
#  list(['vodka', 'orange_juice'])
#  list(['egg', 'heavy_cream', 'sugar', 'egg_yolk', 'grand_marnier', 'kahlua', 'chocolate_chip', 'vanilla', 'whipped_cream'])
#  list(['shrimp', 'butter', 'green_onion', 'oil', 'garlic', 'lemon_juice', 'salt', 'parsley', 'hot_sauce'])
#  list(['cauliflower', 'salt', 'garlic', 'italian_dressing', 'salad_oil', 'sour_cream'])
#  list(['brown_sugar', 'granulated_sugar', 'egg', 'butter', 'vanilla', 'flour', 'baking_soda', 'salt', 'chocolate_chip', 'walnut'])
#  list(['egg', 'milk', 'flour', 'baking_powder', 'salt', 'cooking_oil', 'powdered_sugar'])
#  list(['pea', 'bay_leaf', 'salt', 'water', 'ham_hock', 'onion', 'garlic', 'celery', 'potato', 'carrot', 'red_wine', 'mustard', 'thyme', 'sesame_oil', 'vinegar', 'tomato', 'parsley'])
#  list(['broccoli', 'egg', 'cream_of_celery_soup', 'milk', 'onion', 'swiss_cheese'])
#  list(['egg', 'apple', 'sugar', 'brown_sugar', 'baking_soda', 'cinnamon', 'flour', 'water', 'vegetable_oil', 'raisin', 'pecan', 'salt', 'nutmeg'])
#  list(['yeast', 'warm_water', 'sugar', 'butter', 'flour', 'milk', 'egg', 'salt', 'sugar'])
#  list(['butter', 'milk', 'yeast', 'sugar', 'water', 'flour', 'salt', 'butter'])
#  list(['butter', 'brown_sugar', 'egg', 'flour', 'baking_powder', 'ground_cinnamon', 'salt', 'milk', 'almond', 'honey', 'nut'])
#  list(['margarine', 'egg', 'sugar', 'vanilla', 'salt', 'bread', 'milk', 'raisin', 'nutmeg', 'cinnamon'])
#  list(['ground_beef', 'onion', 'tomato_sauce', 'wide_egg_noodle', 'cream_cheese', 'sour_cream', 'cottage_cheese', 'salt'])
#  list(['corn_flake', 'butter', 'cream_cheese', 'cranberry_sauce'])
#  list(['unsalted_butter', 'canola_oil', 'onion', 'chile', 'salt', 'pepper'])
#  list(['oil', 'water', 'brown_gravy_mix', 'soy_sauce', 'ground_ginger', 'red_pepper', 'chestnut', 'green_onion', 'rice'])
#  list(['orange_juice'])
#  list(['bread', 'hamburger_meat', 'onion', 'bell_pepper', 'velveeta_cheese', 'cheddar_cheese_soup'])
#  list(['bean', 'brown_sugar', 'dry_mustard', 'ketchup', 'bacon', 'onion'])
#  list(['apple', 'sugar', 'egg', 'oil', 'walnut', 'vanilla', 'flour', 'baking_soda', 'salt', 'cinnamon'])
#  list(['cream_cheese', 'cheddar_cheese', 'onion', 'green_pepper', 'pimento', 'worcestershire_sauce', 'lemon_juice', 'walnut'])
#  list(['egg', 'sugar', 'sour_cream', 'butter', 'baking_powder', 'flour'])
#  list(['ham', 'pickle_relish', 'mayonnaise', 'egg'])
#  list(['ground_beef', 'onion', 'tomato_soup', 'elbow_macaroni', 'american_cheese', 'salt'])
#  list(['sugar', 'cornstarch', 'salt', 'coconut', 'egg_yolk', 'milk', 'water', 'vanilla', 'coconut'])
#  list(['butter', 'margarine', 'sugar', 'egg', 'sour_cream', 'vanilla', 'flour', 'baking_powder', 'salt', 'nut', 'cinnamon', 'sugar'])
#  list(['sugar', 'flour', 'egg', 'vanilla', 'milk', 'butter'])
#  list(['zucchini', 'salt', 'tarragon', 'lemon_juice', 'olive_oil', 'chive', 'fresh_ground_black_pepper'])
#  list(['flour', 'salt', 'sugar', 'baking_powder', 'baking_soda', 'sour_cream', 'butter', 'raisin'])
#  list(['butter', 'brown_sugar', 'light_corn_syrup', 'condensed_milk', 'vanilla', 'salt'])
#  list(['chicken', 'onion_soup', 'preserve'])
#  list(['white_bread', 'mozzarella_cheese', 'butter', 'tomato'])
#  list(['shallot', 'rice_vinegar', 'oil', 'fresh_ginger', 'sesame_oil', 'orange', 'baby_spinach', 'avocado'])
#  list(['whole_wheat_flour', 'water', 'salt', 'oil', 'whole_wheat_flour', 'butter'])
#  list(['pastry_shell', 'baking_chocolate', 'condensed_milk', 'almond_extract', 'whipping_cream', 'cherry_pie_filling', 'almond'])
#  list(['ketchup', 'soy_sauce', 'sugar', 'mirin', 'worcestershire_sauce', 'allspice', 'mustard', 'pork_cutlet', 'salt', 'flour', 'egg', 'breadcrumb', 'vegetable_oil', 'cabbage', 'lemon', 'white_rice'])
#  list(['cream_cheese', 'cheddar_cheese', 'salsa', 'hormel_chili', 'black_olive'])
#  list(['water', 'sugar', 'lemon_juice'])
#  list(['bread_cube', 'milk', 'butter', 'salt', 'sugar', 'egg', 'vanilla', 'cinnamon', 'raisin'])
#  list(['yellow_onion', 'red_onion', 'egg'])
#  list(['chicken', 'sour_cream', 'lemon_juice', 'worcestershire_sauce', 'celery_salt', 'pepper', 'paprika', 'salt', 'garlic_salt', 'butter', 'canola_oil', 'butter'])
#  list(['beef', 'cream_cheese', 'horseradish', 'sour_cream', 'parmesan_cheese'])
#  list(['sweet_italian_sausage', 'hot_italian_sausage', 'extra_virgin_olive_oil', 'garlic', 'onion', 'cubanelle_pepper', 'red_bell_pepper', 'salt', 'pepper', 'hot_pepper', 'submarine_roll', 'extra_virgin_olive_oil', 'butter', 'garlic', 'italian_seasoning'])
#  list(['peanut_butter', 'honey', 'vanilla', 'milk', 'salt', 'powdered_sugar'])
#  list(['fruit_cocktail', 'pineapple', 'cream_cheese', 'dream_whip'])
#  list(['dill_pickle', 'tabasco_sauce', 'sugar'])
#  list(['vidalia_onion', 'butter', 'plain_yogurt', 'lemon_juice', 'salt', 'pepper', 'parsley', 'brown_sugar'])
#  list(['egg', 'milk', 'breadcrumb', 'lemon_pepper', 'dill_weed', 'garlic', 'salmon'])
#  list(['cream_cheese', 'basil', 'parsley'])
#  list(['noodle', 'butter', 'cream', 'cheese', 'salt', 'white_pepper', 'parsley'])
# ...
#  list(['brown_sugar', 'marshmallow_cream', 'pet_milk', 'butter', 'butterscotch_chip'])
#  list(['red_salmon', 'cream_cheese', 'ham', 'lemon_juice', 'liquid_smoke', 'onion_powder', 'paprika'])
#  list(['onion', 'zucchini', 'basil', 'pepper', 'provolone_cheese', 'ricotta_cheese', 'egg'])
#  list(['lime_juice', 'honey', 'red_snapper', 'chili_powder'])
#  list(['carrot', 'celery_root', 'zucchini', 'garlic', 'mustard', 'tarragon_vinegar', 'lemon_juice', 'olive_oil', 'salt', 'fresh_ground_pepper', 'fresh_basil'])
#  list(['cream_cheese', 'marshmallow_creme'])
#  list(['ricotta_cheese', 'mozzarella_cheese', 'parmesan_cheese', 'pepperoni'])
#  list(['pumpkin_seed', 'salt', 'water'])
#  list(['salmon_fillet', 'salt', 'pepper', 'mango_salsa', 'mango', 'red_bell_pepper', 'red_onion', 'fresh_cilantro', 'lime_juice'])
#  list(['ground_pork', 'ground_beef', 'milk', 'onion', 'white_bread', 'salt', 'pepper', 'ginger', 'allspice'])
#  list(['boiling_water', 'sugar', 'water', 'milk', 'salt'])
#  list(['orange', 'fruit_cocktail', 'pineapple', 'marshmallow', 'water', 'nut', 'banana'])
#  list(['linguine', 'butter', 'onion', 'flour', 'clam_juice', 'cream', 'lump_crabmeat', 'salt', 'parmesan_cheese', 'fresh_parsley', 'lemon_juice'])
#  list(['yeast', 'warm_water', 'milk', 'oleo', 'sugar', 'salt', 'egg', 'bread_flour', 'egg_white', 'sesame_seed'])
#  list(['bean', 'cheddar_cheese', 'sour_cream', 'green_onion', 'taco_sauce', 'chili_powder', 'salt'])
#  list(['egg', 'sugar', 'flour', 'vanilla', 'milk'])
#  list(['baguette', 'garlic', 'cooking_spray', 'fontina_cheese', 'fresh_basil', 'red_pepper'])
#  list(['pineapple', 'mayonnaise', 'mustard', 'curry_powder', 'salt', 'chicken', 'celery', 'green_onion', 'almond', 'raisin'])
#  list(['pita_bread', 'chunky_salsa', 'cheddar_cheese', 'vegetarian_ground_beef', 'whole_kernel_corn', 'avocado'])
#  list(['butter', 'sugar', 'flour'])
#  list(['shortening', 'egg', 'brown_sugar', 'flour', 'baking_powder', 'salt', 'nut', 'chocolate_chip'])
#  list(['butter', 'corn_syrup', 'sugar', 'ground_cinnamon', 'salt', 'pecan'])
#  list(['peanut_butter', 'corn_syrup', 'powdered_sugar', 'milk'])
#  list(['banana', 'chocolate_chip', 'marshmallow'])
#  list(['tomato_soup', 'cream_cheese', 'unflavored_gelatin', 'water', 'mayonnaise', 'celery', 'onion', 'shrimp', 'salt', 'paprika', 'tabasco_sauce', 'worcestershire_sauce', 'horseradish', 'cracker'])
#  list(['onion', 'tomato', 'pepper', 'cilantro', 'egg', 'flour_tortilla', 'cheddar_cheese', 'sour_cream', 'guacamole'])
#  list(['popcorn', 'butter', 'garlic', 'parmesan_cheese', 'salt', 'basil'])
#  list(['butter', 'condensed_milk', 'golden_syrup', 'brown_sugar', 'cream_of_tartar', 'pistachio'])
#  list(['lime', 'water', 'pineapple', 'mayonnaise', 'cream', 'velveeta_cheese'])
#  list(['cream_cheese', 'sugar', 'egg_yolk', 'vanilla', 'crescent_roll', 'egg', 'sugar', 'pecan', 'ground_cinnamon'])
#  list(['green_bean', 'wax_bean', 'kidney_bean', 'celery', 'onion', 'sweet_pepper', 'vinegar', 'sugar', 'water', 'oil'])
#  list(['cake_mix', 'egg', 'butter', 'pumpkin_pie_spice', 'cream_cheese', 'condensed_milk', 'pumpkin', 'salt', 'nut'])
#  list(['olive_oil', 'lime_juice', 'parsley', 'fresh_basil_leaf', 'cilantro', 'garlic', 'salt', 'black_pepper'])
#  list(['light_brown_sugar', 'flour', 'pecan', 'butter', 'cream_cheese', 'sugar', 'egg', 'milk', 'lemon_juice', 'vanilla_extract'])
#  list(['milk', 'butter', 'egg', 'white_sugar', 'vanilla', 'flour', 'baking_powder', 'peanut_butter', 'milk_chocolate'])
#  list(['chicken', 'swiss_cheese', 'cream_of_chicken_soup', 'white_wine', 'herb_seasoned_stuffing_mix', 'butter'])
#  list(['condensed_milk', 'chocolate_syrup', 'vanilla', 'brandy', 'instant_coffee', 'coconut_extract', 'almond_extract'])
#  list(['chicken_stock', 'garlic', 'sage', 'salt', 'extra_virgin_olive_oil', 'egg', 'sugar_snap_pea', 'quinoa'])
#  list(['flour', 'sugar', 'baking_soda', 'cinnamon', 'salt', 'egg', 'vegetable_oil', 'vanilla', 'carrot', 'apple', 'raisin', 'shredded_coconut', 'almond'])
#  list(['hamburger', 'spaghetti_sauce', 'shell_macaroni', 'sour_cream', 'cream_cheese'])
#  list(['elbow_macaroni', 'cold_water', 'egg_yolk', 'mustard', 'sugar', 'vinegar', 'mayonnaise', 'onion', 'celery'])
#  list(['chocolate_chip', 'coffee', 'rum', 'egg', 'sugar', 'whipping_cream'])
#  list(['buckwheat_flour', 'rice_flour', 'coconut_oil', 'soymilk', 'arrowroot', 'salt', 'oil'])
#  list(['butter', 'onion', 'flour', 'dill_pickle', 'pickle_juice', 'water', 'dill_weed', 'whipping_cream', 'salt'])
#  list(['flour', 'active_dry_yeast', 'milk', 'butter', 'sugar', 'salt', 'egg', 'pesto_sauce', 'parmesan_cheese'])
#  list(['egg_noodle', 'margarine', 'ground_beef', 'spaghetti_sauce', 'velveeta_cheese', 'mozzarella_cheese'])
#  list(['flour', 'baking_powder', 'baking_soda', 'cinnamon', 'salt', 'sugar', 'oil', 'egg', 'pineapple', 'nut', 'coconut', 'carrot'])
#  list(['butter', 'mushroom', 'flour', 'salt', 'pepper', 'cream', 'milk', 'haddock', 'shrimp', 'frozen_pea', 'cheddar_cheese', 'lump_crabmeat', 'pimiento', 'paprika'])
#  list(['graham_cracker_pie_crust', 'egg', 'sugar', 'flour', 'vanilla_sugar'])
#  list(['bell_pepper', 'onion', 'red_wine_vinegar', 'soy_sauce', 'brown_sugar', 'garlic', 'garlic', 'onion_flake', 'ground_ginger', 'black_pepper'])
#  list(['sugar', 'pecan', 'milk', 'margarine', 'sugar', 'cinnamon'])
#  list(['butter', 'white_sugar', 'almond', 'chocolate_chip', 'almond'])
#  list(['biscuit_mix'])
#  list(['milk', 'water', 'sugar', 'active_dry_yeast', 'vegetable_oil', 'salt', 'garlic', 'onion', 'bread_flour'])
#  list(['soup', 'milk', 'carrot', 'clam', 'thyme', 'butter', 'bacon'])
#  list(['egg', 'milk', 'salt', 'vanilla', 'milk', 'nutmeg'])
#  list(['water', 'honey', 'active_dry_yeast', 'spelt_flour', 'salt', 'olive_oil'])
#  list(['corn', 'cheddar_cheese', 'egg_yolk', 'chive', 'salt', 'egg_white', 'cream_of_tartar'])
#  list(['semolina', 'whole_wheat_flour', 'sugar', 'ghee', 'water'])
#  list(['shortening', 'chocolate_square', 'sugar', 'egg', 'vanilla', 'flour', 'baking_powder', 'salt', 'sugar'])
#  list(['onion', 'green_pepper', 'ground_beef', 'tomato_sauce', 'kidney_bean', 'chili_powder'])
#  list(['rice_vinegar', 'sugar', 'hot_sauce', 'vegetable_oil', 'egg', 'salt', 'black_pepper', 'black_sesame_seed', 'cilantro'])
#  list(['cereal', 'butter', 'peanut_butter', 'chocolate_chip', 'powdered_sugar'])
#  list(['brown_sugar', 'oleo', 'egg', 'flour', 'vanilla', 'chocolate_chip', 'nut'])
#  list(['garlic', 'olive_oil', 'basil', 'cannellini_bean', 'salt', 'bay_leaf', 'tomato', 'italian_parsley', 'chili_flake', 'salt', 'lemon_juice', 'ricotta_salata', 'baguette'])
#  list(['basmati_rice', 'cold_water', 'salt'])
#  list(['cottage_cheese', 'cream_cheese', 'sour_cream', 'parsley_flake', 'lasagna_noodle', 'spaghetti_sauce', 'ground_turkey', 'mozzarella_cheese'])
#  list(['tomato', 'red_bell_pepper', 'green_bell_pepper', 'red_onion', 'fresh_cilantro', 'lime_juice', 'olive_oil', 'salt', 'ground_cumin', 'chili_powder', 'pepper', 'black_bean', 'kernel_corn'])
#  list(['butter', 'brown_sugar', 'sugar', 'egg', 'maple_syrup', 'flour', 'baking_soda', 'salt', 'bacon'])
#  list(['bisquick', 'butter', 'water'])
#  list(['graham_cracker_crust', 'yogurt', 'fruit'])
#  list(['green_bean', 'catsup', 'brown_sugar', 'onion', 'bacon'])
#  list(['egg', 'sugar', 'flour', 'baking_powder', 'milk', 'vegetable_oil', 'almond_flavoring', 'salt'])
#  list(['cream_cheese', 'cheddar_cheese', 'scallion', 'black_pepper', 'dill', 'garlic_salt', 'paprika'])
#  list(['broccoli', 'vidalia_onion', 'sunflower_seed', 'raisin', 'mayonnaise', 'vinegar', 'sugar'])
#  list(['mint', 'sugar'])
#  list(['onion', 'green_pepper', 'ground_beef', 'tomato_sauce', 'whole_kernel_corn', 'sugar', 'salt', 'chili_powder', 'pepper', 'american_cheese'])
#  list(['onion_soup', 'water', 'celery', 'poultry_seasoning', 'butter', 'breadcrumb'])
#  list(['onion', 'water', 'margarine', 'mayonnaise', 'american_cheese', 'pimiento', 'parsley', 'bread'])
#  list(['rum', 'powdered_sugar', 'butter'])
#  list(['rice_vinegar', 'maple_syrup', 'soy_sauce', 'sesame_oil', 'gingerroot', 'green_cabbage', 'red_cabbage', 'carrot', 'green_onion', 'apple'])
#  list(['sour_cream', 'onion', 'avocado', 'dill'])
#  list(['salad_oil', 'sugar', 'egg', 'apple', 'flour', 'baking_powder', 'baking_soda', 'salt', 'cinnamon', 'vanilla'])
#  list(['noodle', 'chocolate_chip', 'raisin'])
#  list(['sugar', 'oleo', 'egg', 'coconut', 'raisin', 'pecan', 'vanilla', 'vinegar'])
#  list(['butter', 'shortening', 'sugar', 'flour', 'egg', 'baking_powder', 'milk', 'coconut_extract', 'rum', 'butter', 'lemon_extract', 'vanilla'])
#  list(['sugar', 'buttermilk', 'egg', 'cornstarch', 'margarine', 'pecan', 'vanilla'])
#  list(['elbow_macaroni', 'cheddar_cheese', 'butter', 'flour', 'onion_powder', 'salt'])
#  list(['chicken', 'bourbon_whiskey', 'brown_sugar', 'ketchup', 'worcestershire_sauce', 'white_vinegar', 'lemon_juice', 'garlic', 'mustard', 'salt'])
#  list(['oil', 'cocoa', 'brown_sugar', 'white_sugar', 'egg', 'vanilla', 'flour', 'nut'])
#  list(['mushroom', 'butter', 'onion', 'pepperoni', 'green_pepper', 'garlic', 'ritz_cracker', 'parmesan_cheese', 'parsley', 'seasoning_salt', 'oregano', 'chicken_broth'])
#  list(['herb', 'chicken_breast', 'pecan', 'butter', 'water', 'broccoli_floret', 'red_bell_pepper', 'scallion', 'vinaigrette', 'vegetable_oil', 'white_wine_vinegar', 'orange_juice', 'orange_peel', 'honey', 'salt', 'ground_black_pepper'])
#  list(['pork_chop', 'pepper', 'paprika', 'chicken_bouillon_cube', 'onion', 'water'])
#  list(['sesame_seed', 'soy_sauce', 'apple_juice_concentrate', 'orange_juice', 'ground_ginger', 'dry_mustard', 'cornstarch', 'cold_water', 'chicken_breast_halve', 'orange', 'rice'])
#  list(['almond', 'sugar', 'unsalted_butter', 'egg', 'vanilla', 'almond_extract', 'flour', 'salt'])
#  list(['flour', 'baking_soda', 'baking_powder', 'ground_cinnamon', 'salt', 'egg', 'vegetable_oil', 'sugar', 'golden_brown_sugar', 'orange_marmalade', 'orange_juice', 'carrot', 'walnut', 'cream_cheese', 'powdered_sugar', 'orange_marmalade', 'unsalted_butter', 'walnut'])
#  list(['shortening', 'brown_sugar', 'egg', 'chocolate', 'vanilla', 'flour', 'baking_powder', 'salt', 'milk', 'nut'])
#  list(['frozen_hash_brown', 'flour', 'egg', 'margarine', 'onion', 'water', 'salt', 'vegetable_oil'])
#  list(['butter', 'rice', 'chicken_bouillon', 'broccoli'])
#  list(['flour', 'sugar', 'baking_soda', 'cinnamon', 'salt', 'cooking_oil', 'pineapple', 'egg', 'banana', 'vanilla'])
#  list(['cornish_hen', 'butternut_squash', 'onion', 'red_bell_pepper', 'celery', 'wild_rice', 'gorgonzola', 'fresh_thyme', 'fresh_rosemary', 'butter', 'salt', 'pepper', 'currant_jelly', 'salt', 'pepper', 'chicken_broth'])
#  list(['onion', 'butter']) list(['flour', 'milk', 'sugar', 'mayonnaise'])
#  list(['milk', 'water', 'egg', 'butter', 'salt', 'bread_flour', 'sugar', 'yeast'])
#  list(['milk', 'sugar', 'egg', 'flour', 'salt', 'heavy_cream'])
#  list(['sugar', 'flour', 'cinnamon', 'nutmeg', 'allspice', 'pie_shell', 'clove', 'water', 'vinegar', 'egg', 'butter'])
#  list(['milk', 'active_dry_yeast', 'sugar', 'bread_flour', 'salt', 'unsalted_butter', 'egg', 'sesame_seed'])
#  list(['ground_beef', 'onion', 'salt', 'pepper', 'tomato_soup', 'ketchup', 'bun'])
#  list(['vegetable_oil', 'raisin', 'garlic', 'pine_nut', 'gala_apple', 'italian_sausage', 'spinach', 'parmesan_cheese'])
#  list(['carrot', 'honey', 'mustard', 'ground_cumin', 'ground_cinnamon', 'butter', 'salt', 'pepper', 'parsley'])
#  list(['italian_sausage', 'bell_pepper', 'mozzarella_cheese', 'crescent_roll'])
#  list(['popcorn', 'butter', 'light_corn_syrup'])
#  list(['macaroni', 'broccoli_floret', 'carrot', 'sweetcorn', 'butter', 'flour', 'milk', 'mustard', 'cheddar_cheese', 'breadcrumb'])
#  list(['fresh_spinach', 'creme_fraiche', 'nutmeg', 'salt', 'nut'])
#  list(['olive_oil', 'butter', 'garlic', 'broccoli', 'chicken_broth', 'fresh_basil', 'rigatoni_pasta', 'fresh_parsley', 'fresh_ground_pepper', 'parmesan_cheese'])
#  list(['deer', 'salt', 'ground_ginger', 'brown_sugar', 'black_pepper', 'cayenne_pepper', 'garlic', 'pineapple_juice', 'soy_sauce'])
#  list(['chicken_breast', 'filet_mignon', 'bacon', 'butter', 'onion', 'green_pepper', 'worcestershire_sauce', 'salt'])
#  list(['white_bread', 'cream_cheese', 'butter', 'sugar', 'cinnamon', 'egg_yolk'])
#  list(['olive_oil', 'red_pepper', 'ground_cumin', 'sweet_paprika', 'ground_turmeric', 'ground_lamb', 'egg', 'cilantro', 'parsley', 'goat_cheese'])
#  list(['chicken', 'salt', 'tarragon'])
#  list(['margarine', 'celery', 'mayonnaise', 'sour_cream', 'lemon_juice', 'salt', 'pepper', 'chicken', 'almond', 'mushroom', 'potato_chip'])
#  list(['egg', 'powdered_sugar', 'ground_nut'])
#  list(['bread', 'cheddar_cheese', 'egg', 'milk', 'salt', 'dry_mustard', 'american_cheese'])
#  list(['water', 'yeast', 'powdered_milk', 'sugar', 'oil', 'salt', 'flour'])
#  list(['cocoa', 'baking_soda', 'butter', 'boiling_water', 'sugar', 'egg', 'flour', 'vanilla', 'salt', 'nut', 'chocolate_chip'])
#  list(['cannellini_bean', 'chicken', 'onion', 'red_pepper', 'pepper', 'garlic', 'ground_cumin', 'salt', 'oregano', 'chicken_broth', 'cheese', 'tortilla_chip'])
#  list(['sugar', 'pancake_mix', 'baking_powder', 'pecan', 'egg'])
#  list(['margarine', 'parmesan_cheese'])
#  list(['flour', 'sugar', 'cinnamon', 'butter', 'cocoa', 'water', 'oil', 'egg', 'buttermilk', 'vanilla'])
#  list(['milk', 'strawberry', 'pineapple'])
#  list(['boiling_water', 'oat', 'sugar', 'brown_sugar', 'margarine', 'egg', 'flour', 'baking_soda', 'salt', 'cocoa', 'chocolate_chip', 'walnut'])
#  list(['radish', 'salt', 'chicken', 'salt', 'sesame_oil', 'black_pepper'])
#  list(['chicken', 'bacon', 'white_onion', 'garlic', 'red_pepper', 'thyme', 'rice', 'white_wine', 'parmesan_cheese', 'kosher_salt', 'parsley'])
#  list(['butter', 'onion', 'celery', 'carrot', 'flour', 'milk', 'seafood_stock', 'potato', 'worcestershire_sauce', 'salt', 'pepper', 'shrimp', 'clam', 'lump_crabmeat', 'cream_cheese', 'fresh_parsley'])
#  list(['egg', 'flour', 'sugar', 'mustard', 'pineapple', 'marshmallow'])
#  list(['sausage', 'ground_beef', 'cheddar_cheese', 'bisquick', 'garlic'])
#  list(['margarine', 'bacon', 'fresh_corn', 'water', 'salt', 'sugar', 'pepper', 'flour'])
#  list(['chicken', 'soy_sauce', 'salt', 'pepper'])
#  list(['oatmeal', 'flour', 'baking_powder', 'milk', 'sugar', 'egg', 'salt'])
#  list(['chocolate_chip_cookie', 'butter', 'chocolate_ice_cream', 'chocolate', 'whipped_cream', 'chocolate_chip_cookie'])
#  list(['egg', 'sugar', 'vanilla', 'milk', 'flour', 'baking_powder', 'bread'])
#  list(['egg', 'ham', 'green_pepper', 'onion', 'cheddar_cheese'])
#  list(['broccoli', 'butter', 'velveeta_cheese', 'milk', 'cracker'])
#  list(['tomato_soup', 'catsup', 'salt_pork', 'onion', 'butter', 'black_pepper', 'cayenne_pepper', 'worcestershire_sauce', 'salt', 'catfish_fillet'])
#  list(['chocolate_chip', 'walnut'])
#  list(['orange_juice_concentrate', 'balsamic_vinegar', 'honey', 'scallion', 'bibb_lettuce', 'orange', 'chestnut'])
#  list(['yellow_squash', 'onion', 'salt', 'pepper', 'cracker', 'egg', 'cheddar_cheese'])
#  list(['butter', 'brown_sugar', 'light_corn_syrup', 'vanilla', 'salt', 'baking_soda'])
#  list(['biscuit', 'brown_sugar', 'margarine'])
#  list(['brown_sugar', 'cane_syrup', 'unsalted_butter', 'bread', 'egg', 'milk', 'vanilla', 'salt'])
#  list(['green_pepper', 'ground_beef', 'egg', 'tomato_juice', 'onion', 'rice', 'salt'])
#  list(['cooking_spray', 'ketchup'])
#  list(['flour', 'cocoa', 'baking_soda', 'salt', 'bittersweet_chocolate', 'corn_oil', 'muscovado_sugar', 'corn_syrup', 'water', 'vanilla', 'egg_white', 'cooking_spray'])
#  list(['hamburger', 'cracker_crumb', 'onion', 'pet_milk', 'salt', 'mushroom_soup'])
#  list(['tea', 'pineapple_juice', 'orange_juice', 'frozen_lemonade', 'clove', 'cinnamon'])
#  list(['sesame_seed', 'vegetable_oil', 'ginger', 'spinach', 'vegetable_broth', 'sesame_oil', 'soy_sauce'])
#  list(['egg', 'sugar', 'heavy_cream', 'flour', 'butter', 'salt', 'apple'])
#  list(['salt', 'water', 'banana_pepper', 'vinegar', 'water', 'sugar', 'horseradish', 'garlic'])
#  list(['portabella_mushroom', 'baby_portabella_mushroom', 'olive_oil', 'fresh_ground_black_pepper', 'sage_leaf', 'whole_wheat_baguette'])]

# %%
X_train, X_val, y_train, y_val= train_test_split(subset, subset['embeddings'], test_size= 0.2)

# %%
EMBEDDING_DIMENSIONS = 300

def construct_embedding_matrix(embeddings):
    num_ing = len(embeddings)

    # initialize a matrix of zeros
    embedding_matrix = np.zeros((num_ing, EMBEDDING_DIMENSIONS)) # each embedding has 300 dimensions

    next_row = 0

    for i in embeddings:
        v = embeddings.get(i)
        embedding_matrix[next_row] = v
        next_row+=1
    
    return embedding_matrix

# %%
embedding_matrix = construct_embedding_matrix(ing_embeddings)

# %%
embedding_matrix
# Out:
# array([[-0.10600116,  0.04714949,  0.10841199, ..., -0.03144248,
#         -0.06629407, -0.1286629 ],
#        [-0.01582931,  0.09736368, -0.00062261, ..., -0.09226537,
#         -0.12149926, -0.12204846],
#        [-0.10132008,  0.03372396,  0.06472784, ..., -0.22692445,
#         -0.04366636, -0.20344618],
#        ...,
#        [-0.19128327,  0.17544127, -0.09963894, ..., -0.20900002,
#         -0.17799097, -0.1547064 ],
#        [ 0.02008764,  0.04900858, -0.26409724, ..., -0.19495088,
#         -0.16633987, -0.21576235],
#        [ 0.20899913, -0.15171458, -0.25460058, ..., -0.18800448,
#         -0.08664556, -0.07758268]])

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
MAX_SEQUENCE_LENGTH= 100

# %%
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D, Dropout
from keras.initializers import Constant
from keras.optimizers import Adam

# %%
#print(type(X_train['start_ingredient']))
import numpy as np

x_train_array= X_train
x_train_array= np.asarray(x_train_array)

#print(type(v), v)

x_val_array= X_val
x_val_array= np.asarray(x_val_array)

y_train= np.asarray(y_train)
y_val= np.asarray(y_val)
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>

# %%
[print(i.shape, i.dtype) for i in model.inputs]
[print(o.shape, o.dtype) for o in model.outputs]
[print(l.name, l.input_shape, l.dtype) for l in model.layers]
# Out:
# (None, 100) <dtype: 'float32'>
# (None, 1) <dtype: 'float32'>
# embedding_17 (None, 100) float32
# dropout_13 (None, 100, 300) float32
# lstm_13 (None, 100, 300) float32
# dense_13 (None, 64) float32
# [None, None, None, None]

# %%
model=Sequential()

embedding=Embedding(len(ing_embeddings), # number of unique tokens
                    EMBEDDING_DIMENSIONS, #number of features
                    embeddings_initializer=Constant(embedding_matrix), # initialize 
                    input_length=MAX_SEQUENCE_LENGTH, 
                    trainable=False)

model.add(embedding)
model.add(Dropout(0.2))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.5))
model.add(Dense(1, activation='sigmoid'))
# compile the model
optimzer = Adam(clipvalue=0.5) # clip value to avoid the gradient exploding

model.compile(optimizer=optimzer, 
              loss='binary_crossentropy', 
              metrics=['acc',f1_m,precision_m, recall_m])

# fit the model
history = model.fit(x_train_array, y_train, 
                    batch_size=32, 
                    epochs=20, 
                    validation_data=(x_val_array,y_val), 
                    verbose=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [102], in <cell line: 21>()
#      16 model.compile(optimizer=optimzer,
#      17               loss='binary_crossentropy',
#      18               metrics=['acc',f1_m,precision_m, recall_m])
#      20 # fit the model
# ---> 21 history = model.fit(x_train_array, y_train,
#      22                     batch_size=32,
#      23                     epochs=20,
#      24                     validation_data=(x_val_array,y_val),
#      25                     verbose=2)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type list).
